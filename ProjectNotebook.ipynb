# %%
# Mathematics Flashcard program

# %% [markdown]
# # Project Title
#
# My program's goal is to teach children basic math in a fun, interactive flash card style.  Topics include basic arithmetic operations, such as addition, subtraction, multiplication and division.

# %% [markdown]
# ## Project Code
#
# This project is a math flashcard quiz application built in Python. To run it, execute the cells in this notebook from top to bottom. The notebook will automatically import the FlashcardQuiz class from module.py.

# %%
import module # your module.py file
import importlib

importlib.reload(module)

from module import FlashcardQuiz

# %%
# Initilize the quiz
quiz = FlashcardQuiz()

quiz.add_flashcard("2 + 3", "5", "Addition")
quiz.add_flashcard("7 - 4", "3", "Subtraction")
quiz.add_flashcard("6 × 2", "12", "Multiplication")
quiz.add_flashcard("8 x 3", "24", "Multiplication")
quiz.add_flashcard("8 ÷ 2", "4", "Division")
quiz.add_flashcard("8 x 5", "40", "Multiplication")
quiz.add_flashcard("4 x 4", "16", "Multiplication")
quiz.add_flashcard("2 + 3", "5", "Addition")
quiz.add_flashcard("8 ÷ 2", "4", "Division")
quiz.add_flashcard("7 × 7", "49", "Multiplication")
quiz.add_flashcard("7 - 4", "3", "Subtraction")
quiz.add_flashcard("81 ÷ 9", "9", "Division")
quiz.add_flashcard("12 + 9", "21", "Addition")
quiz.add_flashcard("9 × 6", "54", "Multiplication")
quiz.add_flashcard("100 - 45", "55", "Subtraction")
quiz.add_flashcard("33 + 67", "100", "Addition")
quiz.add_flashcard("49 ÷ 7", "7", "Division")
quiz.add_flashcard("6 × 2", "12", "Multiplication")
quiz.add_flashcard("15 - 8", "7", "Subtraction")
quiz.add_flashcard("25 + 17", "42", "Addition")
quiz.add_flashcard("72 ÷ 8", "9", "Division")
quiz.add_flashcard("8 × 3", "24", "Multiplication")
quiz.add_flashcard("50 - 27", "23", "Subtraction")
quiz.add_flashcard("7 + 8", "15", "Addition")
quiz.add_flashcard("36 ÷ 6", "6", "Division")
quiz.add_flashcard("11 × 11", "121", "Multiplication")
quiz.add_flashcard("64 - 19", "45", "Subtraction")
quiz.add_flashcard("100 + 250", "350", "Addition")
quiz.add_flashcard("56 ÷ 7", "8", "Division")
quiz.add_flashcard("3 × 9", "27", "Multiplication")
quiz.add_flashcard("20 - 13", "7", "Subtraction")
quiz.add_flashcard("14 + 28", "42", "Addition")
quiz.add_flashcard("100 ÷ 4", "25", "Division")
quiz.add_flashcard("12 × 4", "48", "Multiplication")
quiz.add_flashcard("81 - 36", "45", "Subtraction")
quiz.add_flashcard("8 × 5", "40", "Multiplication")
quiz.add_flashcard("6 × 8", "48", "Multiplication")

# %% [markdown]
# **Quiz by category!**

# %%
card = quiz.quiz_user("Multiplication")
# Out:
# Question: 6 × 2

# %%
quiz.check_answer(card, "4")
# Out:
# False

# %% [markdown]
# **Filter by category**

# %%
quiz.filter_by_category("Addition")
# Out:
# [{'question': '2 + 3', 'answer': '5', 'category': 'Addition'}]

# %% [markdown]
# **Filter by another category**

# %%
quiz.filter_by_category("Division")
# Out:
# [{'question': '8 ÷ 2', 'answer': '4', 'category': 'Division'},
#  {'question': '4 x 4', 'answer': '16', 'category': 'Division'}]

# %% [markdown]
# **Test your luck!**

# %%
card = quiz.quiz_user()
# Out:
# Question: 8 x 3

# %%
quiz.check_answer(card, "4")
# Out:
# False

# %% [markdown]
# **Checking incorrect answers (checks the card directly above this)**

# %%
quiz.check_answer(card, "12")
# Out:
# False

# %% [markdown]
# #### Testing
#
# Run your tests. Sample code is provided below; you may need to edit this, depending upon how you've set up your tests.

# %%
# test it out
import unittest
import importlib
import tests

importlib.reload(tests)

unittest.main(module=tests, argv=[''], verbosity=2, exit=False)
# Out:
# test_add_flashcard (tests.TestFlashcardQuiz.test_add_flashcard) ... ok
# test_check_answer (tests.TestFlashcardQuiz.test_check_answer) ... ok
# test_filter_by_category (tests.TestFlashcardQuiz.test_filter_by_category) ... ok
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.005s
#
# OK

# %% [markdown]
# #### GenAI Statement
#
# I utilised Generative AI to provide me with assurance for my idea. I coded this project to the best of my ability and used AI to help with debugging. At one point, I used AI to help me create the def filter_by_category(self, category). Using it for debugging also helped as it allowed me to understand where I was going wrong, and I often used GenAI to ask why I taught this, and why I would make a mistake like this which would allow me to engage with the material at a deeper level and gain a more conceptual understanding of the material.

# %% [markdown]
# #### Extra Credit (*optional*)
#
# Replace all of this text with a brief explanation (~3 sentences) of:
# 1. Your Python Background
# I was very elementary to Python and have absolutely no coding experience. I came into this class not particularly thinking I would enjoy coding, but this class has certainly changed my perception of it. I understood that coding is very logical and persists with a very rule-based understanding. I think this class offered a change to my regular cognitive science classes and this was a lot more technical, which I enjoyed. I also imagine that learning how to code is an invaluable skill in today's world, and I'm very glad I had the opportunity to learn and develop some of those skills.
#
# 3. How your project went above and beyond the requirements of the project and/or how you challenged yourself to learn something new with the final project
# For this project, I went beyond the minimum requirements in several ways. First, I implemented comprehensive data validation and error handling throughout every method in the class. Rather than also just assuming inputs would always be correct, I used instance() checks and also raised specific exceptions (TypeError, ValueError and KeyError) with very descriptive messages. I also designed the FlashcardQuiz class with a category filtering system that allows the quiz to be scoped to specific topics. I believe that this required me to think very carefully about how to structure the data/list of dictionaries so that the filtering would work very smoothly and efficiently. I believe that this went beyond the class design that was taught in lectures.
# Finally, I wrote a comprehensive test suite that goes well beyond the minimum 3 tests required. My test file covers normal cases, edge cases, and error cases for every single method in the class, including testing that specific exceptions are raised with assertRaises.
